# %%
#import packages
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from scipy.stats import cauchy
from scipy.stats import norm

# %%
mun,stdn = 0,1.5
x = np.linspace(-5,5,10000)
sndn = stats.norm(mun, stdn) 
#np.random.normal(loc=0, scale=1.5, size=1000)
#plt.figure(figsize=(4,4))
# plt.plot(x, sndn.pdf(x))

muc,stdc = 0,1.5
sndc = cauchy(muc,stdc)
#np.random.standard_cauchy(1000)
plt.figure(figsize=(4,4))
plt.plot(x, sndn.pdf(x),linestyle='solid',color='blue')
plt.plot(x, sndc.pdf(x),linestyle='-.',color='red')

#plt.xlim(-60, 60)
# plotting a line plot after changing it's width and height
#plt.title('Normal Distribution (Mean =0, STD = 1.5)', fontsize='10')
plt.xlabel('Values of Random Variable X', fontsize='7')
plt.ylabel('Probability', fontsize='7')
plt.legend(['normal distribution','cauchy distribution'])
plt.show()

# %%
x=np.random.normal(loc=0, scale=1.5, size=100000)

# %%
x
# Out:
# array([-2.10352349e-01, -2.03640612e+00, -1.61351020e-01, -1.14795686e+00,
#         6.21026649e-01, -1.19582927e+00,  3.62148733e-01,  1.66615469e+00,
#        -9.67848069e-01,  1.53067126e-01, -9.73598530e-01, -5.64475372e-01,
#         8.34581104e-01, -9.19114997e-03, -7.93940071e-01,  1.43160257e+00,
#         2.14334439e-01, -8.82872986e-01,  9.59245072e-02, -1.44835371e+00,
#        -5.69444666e-01,  1.78254702e+00,  2.30020051e-01, -2.85786865e+00,
#        -4.46248917e-01, -1.71903741e+00,  1.33614744e+00,  1.46688261e+00,
#        -1.25676802e+00,  9.88649982e-01,  2.91621316e-04, -5.22551086e-01,
#        -8.33907744e-01, -4.22129842e-01, -1.62837672e+00, -1.19569323e+00,
#         3.21066428e-01,  8.47236709e-01, -1.70282316e+00,  1.86159257e+00,
#        -2.89013012e+00, -1.29012213e-01,  1.67552552e+00, -6.10574115e-01,
#        -9.35511941e-01, -7.87350702e-01,  1.21090459e+00, -2.11180637e+00,
# ...

# %%
norm.pdf(x,0,1.5)
# Out:
# array([0.24052889, 0.11609155, 0.2621838 , ..., 0.09890878, 0.21863883,
#        0.19908381])

# %%
plt.plot(x, norm.pdf(x,0,1.5),color='blue')

# %%
x1 = np.linspace(-25,175,100000)
sig1, mu1  = 1.5, 0

y = norm.pdf(x1, mu1, sig1)
#y11 = np.exp(-(x-mu1)**2/2*sig1)/(np.sqrt(2*np.pi*sig1))

#plt.plot(x,y11)
plt.plot(x1,y)
plt.show()
